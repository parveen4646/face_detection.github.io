# %%
import pandas as pd
# Out:
# /var/folders/dq/0t1jm_nx0ds_qd3v5j6jnj_m0000gn/T/ipykernel_47842/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
pip install updates tensorflow
# Out:
# Collecting updates
#   Downloading updates-0.1.7.1.tar.gz (4.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (2.15.0)
# Requirement already satisfied: tensorflow-macos==2.15.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.26.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.2.2)
# Building wheels for collected packages: updates
#   Building wheel for updates (setup.py) ... done
#   Created wheel for updates: filename=updates-0.1.7.1-py3-none-any.whl size=4724 sha256=5175d88bd22d6b9886c75ca95bdc60179f4e740a6daefca6e384ae2f66961c91
#   Stored in directory: /Users/Guchi/Library/Caches/pip/wheels/1a/71/3b/06614884a746cb138c5ef0559a7cc5a8b53f4a74298597645d
# Successfully built updates
# Installing collected packages: updates
# Successfully installed updates-0.1.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import mtcnn
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import mtcnn
#
# File ~/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/mtcnn/__init__.py:26
#       1 #!/usr/bin/python3
#       2 # -*- coding: utf-8 -*-
#       3
#    (...)
#      23 # OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE
#      24 # SOFTWARE.
# ---> 26 from mtcnn.mtcnn import MTCNN
#      29 __author__ = "Iván de Paz Centeno"
#      30 __version__= "0.1.0"
#
# File ~/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/mtcnn/mtcnn.py:37
#      34 import pkg_resources
#      36 from mtcnn.exceptions import InvalidImage
# ---> 37 from mtcnn.network.factory import NetworkFactory
#      39 __author__ = "Iván de Paz Centeno"
#      42 class StageStatus(object):
#
# File ~/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/mtcnn/network/factory.py:26
#       1 #!/usr/bin/python3
#       2 # -*- coding: utf-8 -*-
#       3
#    (...)
#      23 # OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE
#      24 # SOFTWARE.
# ---> 26 from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, PReLU, Flatten, Softmax
#      27 from tensorflow.keras.models import Model
#      29 import numpy as np
#
# File ~/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/__init__.py:48
#      45 from tensorflow.python import tf2 as _tf2
#      46 _tf2.enable()
# ---> 48 from tensorflow._api.v2 import __internal__
#      49 from tensorflow._api.v2 import __operators__
#      50 from tensorflow._api.v2 import audio
#
# File ~/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/_api/v2/__internal__/__init__.py:8
#       3 """Public API for tf._api.v2.__internal__ namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__ import autograph
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
#
# File ~/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/_api/v2/__internal__/autograph/__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.autograph namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#       9 from tensorflow.python.autograph.impl.api import tf_convert
#
# File ~/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/autograph/core/ag_ctx.py:21
#      18 import inspect
#      19 import threading
# ---> 21 from tensorflow.python.autograph.utils import ag_logging
#      22 from tensorflow.python.util.tf_export import tf_export
#      25 stacks = threading.local()
#
# File ~/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/autograph/utils/__init__.py:17
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Utility module that contains APIs usable in the generated code."""
# ---> 17 from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#      18 from tensorflow.python.autograph.utils.misc import alias_tensors
#      19 from tensorflow.python.autograph.utils.tensor_list import dynamic_list_append
#
# File ~/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/autograph/utils/context_managers.py:19
#      15 """Various context managers."""
#      17 import contextlib
# ---> 19 from tensorflow.python.framework import ops
#      20 from tensorflow.python.ops import tensor_array_ops
#      23 def control_dependency_on_returns(return_value):
#
# File ~/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:40
#      36 from tensorflow.core.protobuf import config_pb2
#      37 # pywrap_tensorflow must be imported first to avoid protobuf issues.
#      38 # (b/143110113)
#      39 # pylint: disable=invalid-import-order,g-bad-import-order,unused-import
# ---> 40 from tensorflow.python import pywrap_tensorflow
#      41 from tensorflow.python import pywrap_tfe
#      42 # pylint: enable=invalid-import-order,g-bad-import-order,unused-import
#
# File ~/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/pywrap_tensorflow.py:34
#      29 from tensorflow.python.platform import self_check
#      31 # TODO(mdan): Cleanup antipattern: import for side effects.
#      32
#      33 # Perform pre-load sanity checks in order to produce a more actionable error.
# ---> 34 self_check.preload_check()
#      36 # pylint: disable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#      38 try:
#      39   # This import is expected to fail if there is an explicit shared object
#      40   # dependency (with_framework_lib=true), since we do not need RTLD_GLOBAL.
#
# File ~/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/self_check.py:63, in preload_check()
#      50       raise ImportError(
#      51           "Could not find the DLL(s) %r. TensorFlow requires that these DLLs "
#      52           "be installed in a directory that is named in your %%PATH%% "
#    (...)
#      56           "https://support.microsoft.com/help/2977003/the-latest-supported-visual-c-downloads"
#      57           % " or ".join(missing))
#      58 else:
#      59   # Load a library that performs CPU feature guard checking.  Doing this here
#      60   # as a preload check makes it more likely that we detect any CPU feature
#      61   # incompatibilities before we trigger them (which would typically result in
#      62   # SIGILL).
# ---> 63   from tensorflow.python.platform import _pywrap_cpu_feature_guard
#      64   _pywrap_cpu_feature_guard.InfoAboutUnusedCPUFeatures()
#
# ImportError: dlopen(/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/_pywrap_cpu_feature_guard.so, 0x0002): Library not loaded: @rpath/libtensorflow_cc.2.dylib
#   Referenced from: <B54D5CFE-AB88-3E28-A9B0-4F7038FDFBD8> /Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/_pywrap_tensorflow_internal.so
#   Reason: tried: '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/../../_solib_darwin_arm64/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/_pywrap_tensorflow_internal.so.runfiles/org_tensorflow/_solib_darwin_arm64/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/../../_solib_darwin_arm64/_U_S_Stensorflow_Spython_C_Upywrap_Utensorflow_Uinternal.so_Ucclib___Utensorflow/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/_pywrap_tensorflow_internal.so.runfiles/org_tensorflow/_solib_darwin_arm64/_U_S_Stensorflow_Spython_C_Upywrap_Utensorflow_Uinternal.so_Ucclib___Utensorflow/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/../libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/../../../_solib_darwin_arm64/_U_S_Stensorflow_Clibtensorflow_Uframework_Uimport_Ulib___Utensorflow/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/_pywrap_cpu_feature_guard.so.runfiles/org_tensorflow/_solib_darwin_arm64/_U_S_Stensorflow_Clibtensorflow_Uframework_Uimport_Ulib___Utensorflow/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/../../../_solib_darwin_arm64/_U_S_Stensorflow_Spython_C_Upywrap_Utensorflow_Uinternal_Umacos___Utensorflow_Spython/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/_pywrap_cpu_feature_guard.so.runfiles/org_tensorflow/_solib_darwin_arm64/_U_S_Stensorflow_Spython_C_Upywrap_Utensorflow_Uinternal_Umacos___Utensorflow_Spython/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/../libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/../../libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/../../../_solib_darwin_arm64/_U_S_Stensorflow_Clibtensorflow_Uframework_Uimport_Ulib___Utensorflow/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/_pywrap_cpu_feature_guard.so.runfiles/org_tensorflow/_solib_darwin_arm64/_U_S_Stensorflow_Clibtensorflow_Uframework_Uimport_Ulib___Utensorflow/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/../../../_solib_darwin_arm64/_U_S_Stensorflow_Spython_C_Upywrap_Utensorflow_Uinternal_Umacos___Utensorflow_Spython/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/_pywrap_cpu_feature_guard.so.runfiles/org_tensorflow/_solib_darwin_arm64/_U_S_Stensorflow_Spython_C_Upywrap_Utensorflow_Uinternal_Umacos___Utensorflow_Spython/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/libtensorflow_cc.2.dylib' (no such file), '/Users/Guchi/anaconda3/envs/TensorFlow/lib/python3.11/site-packages/tensorflow/python/platform/../libtensorflow_cc.2.dylib' (no such file), '/Us ...

# %%
conda remove tensorflow
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 24.1.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.1.2
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/Guchi/anaconda3/envs/TensorFlow
#
#   removed specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anyio-4.2.0                |  py311hca03da5_0         238 KB
#     bzip2-1.0.8                |       h80987f9_5         129 KB
#     cffi-1.16.0                |  py311h80987f9_0         296 KB
#     comm-0.2.1                 |  py311hca03da5_0          18 KB
#     ipykernel-6.28.0           |  py311hca03da5_0         247 KB
#     ipython-8.20.0             |  py311hca03da5_0         1.4 MB
#     jinja2-3.1.3               |  py311hca03da5_0         361 KB
#     jsonschema-4.19.2          |  py311hca03da5_0         195 KB
#     jsonschema-specifications-2023.7.1|  py311hca03da5_0          17 KB
#     jupyter_events-0.8.0       |  py311hca03da5_0          43 KB
#     jupyter_server-2.10.0      |  py311hca03da5_0         587 KB
#     jupyter_server_terminals-0.4.4|  py311hca03da5_1          28 KB
#     jupyterlab_pygments-0.2.2  |  py311hca03da5_0          19 KB
#     markupsafe-2.1.3           |  py311h80987f9_0          26 KB
#     nbclassic-1.0.0            |  py311hca03da5_0         6.2 MB
#     nbclient-0.8.0             |  py311hca03da5_0         120 KB
#     nest-asyncio-1.6.0         |  py311hca03da5_0          18 KB
#     notebook-shim-0.2.3        |  py311hca03da5_0          27 KB
#     overrides-7.4.0            |  py311hca03da5_0          38 KB
#     pip-23.3.1                 |  py311hca03da5_0         3.3 MB
#     prompt-toolkit-3.0.43      |  py311hca03da5_0         735 KB
#     prompt_toolkit-3.0.43      |       hd3eb1b0_0           5 KB
#     python-3.11.8              |       hb885b13_0        15.5 MB
#     pyyaml-6.0.1               |  py311h80987f9_0         197 KB
#     pyzmq-24.0.1               |  py311h80987f9_0         556 KB
#     referencing-0.30.2         |  py311hca03da5_0          80 KB
#     rpds-py-0.10.6             |  py311hf0e4da2_0         312 KB
#     send2trash-1.8.2           |  py311hca03da5_0          34 KB
#     setuptools-68.2.2          |  py311hca03da5_0         1.2 MB
#     sniffio-1.3.0              |  py311hca03da5_0          18 KB
#     typing-extensions-4.9.0    |  py311hca03da5_1          10 KB
#     typing_extensions-4.9.0    |  py311hca03da5_1          71 KB
#     tzdata-2024a               |       h04d1e81_0         116 KB
#     xz-5.4.6                   |       h80987f9_0         372 KB
#     zeromq-4.3.5               |       h313beb8_0         306 KB
#     ------------------------------------------------------------
#                                            Total:        32.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   jsonschema-specif~ pkgs/main/osx-arm64::jsonschema-specifications-2023.7.1-py311hca03da5_0
#   jupyter_events     pkgs/main/osx-arm64::jupyter_events-0.8.0-py311hca03da5_0
#   jupyter_server_te~ pkgs/main/osx-arm64::jupyter_server_terminals-0.4.4-py311hca03da5_1
#   overrides          pkgs/main/osx-arm64::overrides-7.4.0-py311hca03da5_0
#   prompt_toolkit     pkgs/main/noarch::prompt_toolkit-3.0.43-hd3eb1b0_0
#   python-json-logger pkgs/main/osx-arm64::python-json-logger-2.0.7-py311hca03da5_0
#   pyyaml             pkgs/main/osx-arm64::pyyaml-6.0.1-py311h80987f9_0
#   referencing        pkgs/main/osx-arm64::referencing-0.30.2-py311hca03da5_0
#   rfc3339-validator  pkgs/main/osx-arm64::rfc3339-validator-0.1.4-py311hca03da5_0
#   rfc3986-validator  pkgs/main/osx-arm64::rfc3986-validator-0.1.1-py311hca03da5_0
#   rpds-py            pkgs/main/osx-arm64::rpds-py-0.10.6-py311hf0e4da2_0
#   yaml               pkgs/main/osx-arm64::yaml-0.2.5-h1a28f6b_0
#
# The following packages will be REMOVED:
#
#   _tflow_select-2.2.0-eigen
#   abseil-cpp-20211102.0-hc377ac9_0
#   absl-py-1.4.0-py311hca03da5_0
#   aiohttp-3.9.3-py311h80987f9_0
#   aiosignal-1.2.0-pyhd3eb1b0_0
#   astunparse-1.6.3-py_0
#   backcall-0.2.0-pyhd3eb1b0_0
#   blas-1.0-openblas
#   blinker-1.6.2-py311hca03da5_0
#   brotli-python-1.0.9-py311h313beb8_7
#   c-ares-1.19.1-h80987f9_0
#   cachetools-4.2.2-pyhd3eb1b0_0
#   charset-normalizer-2.0.4-pyhd3eb1b0_0
#   click-8.1.7-py311hca03da5_0
#   cryptography-41.0.3-py311h3c57c4d_0
#   flatbuffers-2.0.0-hc377ac9_0
#   frozenlist-1.4.0-py311h80987f9_0
#   gast-0.4.0-pyhd3eb1b0_0
#   giflib-5.2.1-h80987f9_3
#   google-auth-2.6.0-pyhd3eb1b0_0
#   google-auth-oauthlib-0.5.2-py311hca03da5_0
#   google-pasta-0.2.0-pyhd3eb1b0_0
#   grpc-cpp-1.48.2-h877324c_0
#   grpcio-1.48.2-py311h877324c_0
#   h5py-3.9.0-py311hba6ad2f_0
#   hdf5-1.12.1-h160e8cb_2
#   icu-68.1-hc377ac9_0
#   jpeg-9e-h80987f9_1
#   keras-2.12.0-py311hca03da5_0
#   keras-preprocessing-1.1.2-pyhd3eb1b0_0
#   krb5-1.20.1-h8380606_1
#   libcurl-8.2.1-h0f1d93c_0
#   libedit-3.1.20230828-h80987f9_0
#   libev-4.33-h1a28f6b_1
#   libgfortran-5.0.0-11_3_0_hca03da5_28
#   libgfortran5-11.3.0-h009349e_28
#   libiconv-1.16-h1a28f6b_2
#   libnghttp2-1.52.0-h10c0552_1
#   libopenblas-0.3.21-h269037a_0
#   libpng-1.6.39-h80987f9_0
#   libprotobuf-3.20.3-h514c7bf_0
#   libssh2-1.10.0-h449679c_2
#   libxml2-2.10.4-h372ba2a_0
#   libxslt-1.1.37-habca612_0
#   llvm-openmp-14.0.6-hc6e5704_0
#   lxml-4.9.3-py311h50ffb84_0
#   markdown-3.4.1-py311hca03da5_0
#   multidict-6.0.4-py311h80987f9_0
#   numpy-1.23.5-py311hb2c0538_0
#   numpy-base-1.23.5-py311h9eb1c70_0
#   oauthlib-3.2.2-py311hca03da5_0
#   opt_einsum-3.3.0-pyhd3eb1b0_1
#   pickleshare-0.7.5-pyhd3eb1b0_1003
#   protobuf-3.20.3-py311h313beb8_0
#   pyasn1-0.4.8-pyhd3eb1b0_0
#   pyasn1-modules-0.2.8-py_0
#   pyjwt-2.4.0-py311hca03da5_0
#   pyopenssl-23.2.0-py311hca03da5_0
#   pyrsistent-0.18.0-py311h80987f9_0
#   pysocks-1.7.1-py311hca03da5_0
#   python-flatbuffers-2.0-pyhd3eb1b0_0
#   re2-2022.04.01-hc377ac9_0
#   requests-2.31.0-py311hca03da5_1
#   requests-oauthlib-1.3.0-py_0
#   rsa-4.7.2-pyhd3eb1b0_1
#   scipy-1.11.4-py311hc76d9b0_0
#   snappy-1.1.10-h313beb8_1
#   tensorboard-2.12.1-py311hca03da5_0
#   tensorboard-data-server-0.7.0-py311ha6e5c4f_0
#   tensorboard-plugin-wit-1.8.1-py311hca03da5_0
#   tensorflow-2.12.0-eigen_py311h689d69b_0
#   tensorflow-base-2.12.0-eigen_py311h0a52ebb_0
#   tensorflow-estimator-2.12.0-py311hca03da5_0
#   termcolor-2.1.0-py311hca03da5_0
#   urllib3-2.1.0-py311hca03da5_1
#   werkzeug-2.3.8-py311hca03da5_0
#   wrapt-1.14.1-py311h80987f9_0
#   yarl-1.9.3-py311h80987f9_0
#
# The following packages will be UPDATED:
#
#   anyio                               3.5.0-py311hca03da5_0 --> 4.2.0-py311hca03da5_0
#   bzip2                                    1.0.8-h620ffc9_4 --> 1.0.8-h80987f9_5
#   cffi                               1.15.1-py311h80987f9_3 --> 1.16.0-py311h80987f9_0
#   comm                                0.1.2-py311hca03da5_0 --> 0.2.1-py311hca03da5_0
#   ipykernel                          6.25.0-py311hb6e6a13_0 --> 6.28.0-py311hca03da5_0
#   ipython                            8.15.0-py311hca03da5_0 --> 8.20.0-py311hca03da5_0
#   jinja2                              3.1.2-py311hca03da5_0 --> 3.1.3-py311hca03da5_0
#   jsonschema                         4.17.3-py311hca03da5_0 --> 4.19.2-py311hca03da5_0
#   jupyter_core                        5.3.0-py311hca03da5_0 --> 5.5.0-py311hca03da5_0
#   jupyter_server                     1.23.4-py311hca03da5_0 --> 2.10.0-py311hca03da5_0
#   jupyterlab_pygmen~ pkgs/main/noarch::jupyterlab_pygments~ --> pkgs/main/osx-arm64::jupyterlab_pygments-0.2.2-py311hca03da5_0
#   markupsafe                          2.1.1-py311h80987f9_0 --> 2.1.3-py311h80987f9_0
#   nbclassic                           0.5.5-py311hca03da5_0 --> 1.0.0-py311hca03da5_0
#   nbclient                           0.5.13-py311hca03da5_0 --> 0.8.0-py311hca03da5_0
#   nest-asyncio                        1.5.6-py311hca03da5_0 --> 1.6.0-py311hca03da5_0
#   notebook-shim                       0.2.2-py311hca03da5_0 --> 0.2.3-py311hca03da5_0
#   openssl                                 1.1.1w-h1a28f6b_0 --> 3.0.13-h1a28f6b_0
#   pip                                23.2.1-py311hca03da5_0 --> 23.3.1-py311hca03da5_0
#   prompt-toolkit                     3.0.36-py311hca03da5_0 --> 3.0.43-py311hca03da5_0
#   python                                  3.11.5-hc0d8a6c_0 --> 3.11.8-hb885b13_0
#   pyzmq                              23.2.0-py311h313beb8_0 --> 24.0.1-py311h80987f9_0
#   send2trash         pkgs/main/noarch::send2trash-1.8.0-py~ --> pkgs/main/osx-arm64::send2trash-1.8.2-py311hca03da5_0
#   setuptools                         68.0.0-py311hca03da5_0 --> 68.2.2-py311hca03da5_0
#   sniffio                             1.2.0-py311hca03da5_1 --> 1.3.0-py311hca03da5_0
#   typing-extensions                   4.7.1-py311hca03da5_0 --> 4.9.0-py311hca03da5_1
#   typing_extensions                   4.7.1-py311hca03da5_0 --> 4.9.0-py311hca03da5_1
#   tzdata                                   2023c-h04d1e81_0 --> 2024a-h04d1e81_0
#   wheel              pkgs/main/noarch::wheel-0.35.1-pyhd3e~ --> pkgs/main/osx-arm64::wheel-0.41.2-py311hca03da5_0
#   xz                                       5.4.2-h80987f9_0 --> 5.4.6-h80987f9_0
#   zeromq                                   4.3.4-hc377ac9_0 --> 4.3.5-h313beb8_0
#
#
#
# Downloading and Extracting Packages:
# jinja2-3.1.3         | 361 KB    |                                       |   0%
# pip-23.3.1           | 3.3 MB    |                                       |   0%
#
# sniffio-1.3.0        | 18 KB     |                                       |   0%
#
#
# cffi-1.16.0          | 296 KB    |                                       |   0%
#
#
#
# bzip2-1.0.8          | 129 KB    |                                       |   0%
#
#
#
#
# comm-0.2.1           | 18 KB     |                                       |   0%
#
#
#
#
#
# python-3.11.8        | 15.5 MB   |                                       |   0%
#
#
#
#
#
#
# notebook-shim-0.2.3  | 27 KB     |                                       |   0%
#
#
#
#
#
#
#
# pyzmq-24.0.1         | 556 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# pyyaml-6.0.1         | 197 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# send2trash-1.8.2     | 34 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# xz-5.4.6             | 372 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.8.0       | 120 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_server_termi | 28 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 306 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# referencing-0.30.2   | 80 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# prompt-toolkit-3.0.4 | 735 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipython-8.20.0       | 1.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 116 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclassic-1.0.0      | 6.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# markupsafe-2.1.3     | 26 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.28.0     | 247 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab_pygments- | 19 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# bzip2-1.0.8          | 129 KB    | ####5                                 |  12%
#
# sniffio-1.3.0        | 18 KB     | #################################2    |  90%
#
# sniffio-1.3.0        | 18 KB     | ##################################### | 100%
# pip-23.3.1           | 3.3 MB    | 1                                     |   0%
#
#
# jinja2-3.1.3         | 361 KB    | #6                                    |   4%
#
#
#
#
# comm-0.2.1           | 18 KB     | #################################4    |  90%
#
#
#
#
# comm-0.2.1           | 18 KB     | ##################################### | 100%
#
#
#
# bzip2-1.0.8          | 129 KB    | ##################################### | 100%
#
#
#
#
#
# python-3.11.8        | 15.5 MB   |                                       |   0%
#
#
#
#
#
#
# notebook-shim-0.2.3  | 27 KB     | #####################7                |  59%
#
#
#
#
#
#
# notebook-shim-0.2.3  | 27 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# pyzmq-24.0.1         | 556 KB    | #                                     |   3%
#
#
# cffi-1.16.0          | 296 KB    | ##################################### | 100%
# pip-23.3.1           | 3.3 MB    | ###############8                      |  43%
#
#
#
#
#
#
#
#
# jinja2-3.1.3         | 361 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# send2trash-1.8.2     | 34 KB     | #################6                    |  48%
#
#
#
#
#
# python-3.11.8        | 15.5 MB   | #####9                                |  16%
#
#
#
#
#
#
#
#
#
#
# xz-5.4.6             | 372 KB    | #5                                    |   4%
#
#
#
#
#
#
#
#
#
# send2trash-1.8.2     | 34 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.8.0       | 120 KB    | ####9                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_server_termi | 28 KB     | #####################1                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 306 KB    | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# referencing-0.30.2   | 80 KB     | #######4                              |  20%
#
#
#
#
#
#
#
#
# pyyaml-6.0.1         | 197 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# pyyaml-6.0.1         | 197 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclassic-1.0.0      | 6.2 MB    |                                       |   0%
#
#
#
#
#
# python-3.11.8        | 15.5 MB   | ################                      |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 116 KB    | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipython-8.20.0       | 1.4 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# prompt-toolkit-3.0.4 | 735 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
# xz-5.4.6             | 372 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# xz-5.4.6             | 372 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# pyzmq-24.0.1         | 556 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# pyzmq-24.0.1         | 556 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# markupsafe-2.1.3     | 26 KB     | ######################8               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclassic-1.0.0      | 6.2 MB    | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_server_termi | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_server_termi | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.8.0       | 120 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.8.0       | 120 KB    | ##################################### | 100%
#
#
#
#
#
# python-3.11.8        | 15.5 MB   | #######################1              |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# prompt-toolkit-3.0.4 | 735 KB    | #######################3              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 306 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zeromq-4.3.5         | 306 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.28.0     | 247 KB    | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab_pygments- | 19 KB     | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclassic-1.0.0      | 6.2 MB    | #########7                            |  26%
#
#
#
#
#
# python-3.11.8        | 15.5 MB   | ################################7     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclassic-1.0.0      | 6.2 MB    | ##############7                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# referencing-0.30.2   | 80 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# referencing-0.30.2   | 80 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# markupsafe-2.1.3     | 26 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# markupsafe-2.1.3     | 26 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclassic-1.0.0      | 6.2 MB    | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclassic-1.0.0      | 6.2 MB    | #################################8    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 116 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2024a         | 116 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab_pygments- | 19 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyterlab_pygments- | 19 KB     | ##################################### | 100%
# pip-23.3.1           | 3.3 MB    | ##################################### | 100%
# pip-23.3.1           | 3.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipython-8.20.0       | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipython-8.20.0       | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# prompt-toolkit-3.0.4 | 735 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# prompt-toolkit-3.0.4 | 735 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.28.0     | 247 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.28.0     | 247 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclassic-1.0.0      | 6.2 MB    | ##################################### | 100%
#
#
#
#
#
# python-3.11.8        | 15.5 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install facenet_pytorch
# Out:
# Collecting facenet_pytorch
#   Obtaining dependency information for facenet_pytorch from https://files.pythonhosted.org/packages/40/c1/0a15058f478c8f0f29cacb6e35530b97ead780be99737e62810e71dc477e/facenet_pytorch-2.5.3-py3-none-any.whl.metadata
#   Using cached facenet_pytorch-2.5.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from facenet_pytorch) (1.26.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from facenet_pytorch) (2.31.0)
# Collecting torchvision (from facenet_pytorch)
#   Obtaining dependency information for torchvision from https://files.pythonhosted.org/packages/a8/95/affe174621ebc9b32544a918ae6cb758ac06061d0ee51d783e06906ceba1/torchvision-0.17.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached torchvision-0.17.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting pillow (from facenet_pytorch)
#   Obtaining dependency information for pillow from https://files.pythonhosted.org/packages/46/ce/a84284ab66a278825109b03765d7411be3ff18250da44faa9fb5ea9a16a0/pillow-10.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached pillow-10.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->facenet_pytorch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->facenet_pytorch) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->facenet_pytorch) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->facenet_pytorch) (2024.2.2)
# Collecting torch==2.2.1 (from torchvision->facenet_pytorch)
#   Obtaining dependency information for torch==2.2.1 from https://files.pythonhosted.org/packages/3e/b9/256ab23c859cbcd7d6fb7cb46417a07eac817881a0a68df8ea0c18f45221/torch-2.2.1-cp311-none-macosx_11_0_arm64.whl.metadata
#   Using cached torch-2.2.1-cp311-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Collecting filelock (from torch==2.2.1->torchvision->facenet_pytorch)
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/81/54/84d42a0bee35edba99dee7b59a8d4970eccdd44b99fe728ed912106fc781/filelock-3.13.1-py3-none-any.whl.metadata
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch==2.2.1->torchvision->facenet_pytorch) (4.10.0)
# Collecting sympy (from torch==2.2.1->torchvision->facenet_pytorch)
#   Obtaining dependency information for sympy from https://files.pythonhosted.org/packages/d2/05/e6600db80270777c4a64238a98d442f0fd07cc8915be2a1c16da7f2b9e74/sympy-1.12-py3-none-any.whl.metadata
#   Using cached sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch==2.2.1->torchvision->facenet_pytorch)
#   Obtaining dependency information for networkx from https://files.pythonhosted.org/packages/d5/f0/8fbc882ca80cf077f1b246c0e3c3465f7f415439bdea6b899f6b19f61f70/networkx-3.2.1-py3-none-any.whl.metadata
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2 (from torch==2.2.1->torchvision->facenet_pytorch)
#   Obtaining dependency information for jinja2 from https://files.pythonhosted.org/packages/30/6d/6de6be2d02603ab56e72997708809e8a5b0fbfee080735109b40a3564843/Jinja2-3.1.3-py3-none-any.whl.metadata
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting fsspec (from torch==2.2.1->torchvision->facenet_pytorch)
#   Obtaining dependency information for fsspec from https://files.pythonhosted.org/packages/ad/30/2281c062222dc39328843bd1ddd30ff3005ef8e30b2fd09c4d2792766061/fsspec-2024.2.0-py3-none-any.whl.metadata
#   Downloading fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->torch==2.2.1->torchvision->facenet_pytorch) (2.1.5)
# Collecting mpmath>=0.19 (from sympy->torch==2.2.1->torchvision->facenet_pytorch)
#   Obtaining dependency information for mpmath>=0.19 from https://files.pythonhosted.org/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl.metadata
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached facenet_pytorch-2.5.3-py3-none-any.whl (1.9 MB)
# Using cached pillow-10.2.0-cp311-cp311-macosx_11_0_arm64.whl (3.3 MB)
# Using cached torchvision-0.17.1-cp311-cp311-macosx_11_0_arm64.whl (1.6 MB)
# Using cached torch-2.2.1-cp311-none-macosx_11_0_arm64.whl (59.7 MB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Downloading fsspec-2024.2.0-py3-none-any.whl (170 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 3.4 MB/s eta 0:00:00a 0:00:01
# Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 15.4 MB/s eta 0:00:00
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, pillow, networkx, jinja2, fsspec, filelock, torch, torchvision, facenet_pytorch
#   WARNING: The script isympy is installed in '/Library/Frameworks/Python.framework/Versions/3.11/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
#   WARNING: The scripts convert-caffe2-to-onnx, convert-onnx-to-caffe2 and torchrun are installed in '/Library/Frameworks/Python.framework/Versions/3.11/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
# Successfully installed facenet_pytorch-2.5.3 filelock-3.13.1 fsspec-2024.2.0 jinja2-3.1.3 mpmath-1.3.0 networkx-3.2.1 pillow-10.2.0 sympy-1.12 torch-2.2.1 torchvision-0.17.1
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from facenet_pytorch import InceptionResnetV1

# %%
import pickle

# %%
model = InceptionResnetV1(pretrained='vggface2').eval()

# %%
with open('model.pkl','wb') as f:
    pickle.dump(model,f)

# %%
import tensorflow

# %%
import torch

# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_saved_model('model.pkl')
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open('quantized_model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 3
#       1 import tensorflow as tf
# ----> 3 converter = tf.lite.TFLiteConverter.from_saved_model('model.pkl')
#       4 converter.optimizations = [tf.lite.Optimize.DEFAULT]
#       5 tflite_model = converter.convert()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/lite/python/lite.py:2087, in TFLiteConverterV2.from_saved_model(cls, saved_model_dir, signature_keys, tags)
#    2084   tags = set([_tag_constants.SERVING])
#    2086 with context.eager_mode():
# -> 2087   saved_model = _load(saved_model_dir, tags)
#    2088 if not signature_keys:
#    2089   signature_keys = saved_model.signatures
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/saved_model/load.py:912, in load(export_dir, tags, options)
#     910 if isinstance(export_dir, os.PathLike):
#     911   export_dir = os.fspath(export_dir)
# --> 912 result = load_partial(export_dir, None, tags, options)["root"]
#     913 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/saved_model/load.py:1017, in load_partial(export_dir, filters, tags, options)
#    1012 if tags is not None and not isinstance(tags, set):
#    1013   # Supports e.g. tags=SERVING and tags=[SERVING]. Sets aren't considered
#    1014   # sequences for nest.flatten, so we put those through as-is.
#    1015   tags = nest.flatten(tags)
#    1016 saved_model_proto, debug_info = (
# -> 1017     loader_impl.parse_saved_model_with_debug_info(export_dir))
#    1019 loader = None
#    1020 if (len(saved_model_proto.meta_graphs) == 1 and
#    1021     saved_model_proto.meta_graphs[0].HasField("object_graph_def")):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/saved_model/loader_impl.py:59, in parse_saved_model_with_debug_info(export_dir)
#      46 def parse_saved_model_with_debug_info(export_dir):
#      47   """Reads the savedmodel as well as the graph debug info.
#      48
#      49   Args:
#    (...)
#      57     parsed. Missing graph debug info file is fine.
#      58   """
# ---> 59   saved_model = parse_saved_model(export_dir)
#      61   debug_info_path = file_io.join(
#      62       path_helpers.get_debug_dir(export_dir),
#      63       constants.DEBUG_INFO_FILENAME_PB)
#      64   debug_info = graph_debug_info_pb2.GraphDebugInfo()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/saved_model/loader_impl.py:119, in parse_saved_model(export_dir)
#     117     raise IOError(f"Cannot parse file {path_to_pbtxt}: {str(e)}.") from e
#     118 else:
# --> 119   raise IOError(
#     120       f"SavedModel file does not exist at: {export_dir}{os.path.sep}"
#     121       f"{{{constants.SAVED_MODEL_FILENAME_PBTXT}|"
#     122       f"{constants.SAVED_MODEL_FILENAME_PB}}}")
#     123 return saved_model
#
# OSError: SavedModel file does not exist at: model.pkl/{saved_model.pbtxt|saved_model.pb}
